# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import joblib

# Move 2 directories up to find the root folder
base_dir = os.path.abspath(os.path.join(os.getcwd(), "../.."))
csv_path = os.path.join(base_dir, "data", "sample", "sample_reports.csv")

# Fallback in case the notebook kernel is running at project root
if not os.path.exists(csv_path):
    csv_path = "data/sample/sample_reports.csv"

df = pd.read_csv(csv_path)

print("Dataset loaded successfully! Total records:", len(df))
print(df[["report_id", "description", "sif_potential"]].head())
# Out:
# Dataset loaded successfully! Total records: 100
#   report_id                                        description  sif_potential
# 0  REP-1000  Worker doing welding near pressurized gas line...              1
# 1  REP-1001  Tripped on an extension cord in the office hal...              0
# 2  REP-1002  Entering confined space for inspection without...              1
# 3  REP-1003             Slipped on wet floor in the cafeteria.              0
# 4  REP-1004  Working on a scaffold at 10 meters without saf...              1
